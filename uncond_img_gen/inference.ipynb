# %%
from diffusers import DiffusionPipeline
import  matplotlib.pyplot as plt
path_to_pretrained ='/home/siyuan/image_to_img_generation/uncond_img_gen/output'
pipline = DiffusionPipeline.from_pretrained(path_to_pretrained)
pipline.to("cuda")
# set number of images to generate
ouputs = pipline(output_type='np.array', num_inference_steps=500, batch_size=4)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
plt.imshow(ouputs[0][0])
